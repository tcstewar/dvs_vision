# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
import davis_track
import importlib
importlib.reload(davis_track)
# Out:
# <module 'davis_track' from 'C:\\Users\\Terry\\Documents\\GitHub\\dvs_vision\\davis_track.py'>

# %%
times, images, targets = davis_track.load_data('dvs_data/retinaTest95.events', dt=0.1, decay_time=0.1, merge=3)
N = 5
plt.figure(figsize=(14,8))
indices = np.linspace(0, len(times)-1, N).astype(int)
for i, index in enumerate(indices):
    plt.subplot(1, N, i+1)
    plt.imshow(images[index], vmin=-2, vmax=2)
    plt.xticks([])
    plt.yticks([])
    plt.scatter([targets[index,0]], [targets[index,1]])
# Out:
# C:\Users\Terry\Documents\GitHub\dvs_vision\davis_track.py:154: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   np.add.at(image, [y[s], x[s]], p[s] * np.exp(-dts/decay_time))

# %%
images, targets = davis_track.augment(images, targets, separate_channels=False)
height = images.shape[1]
width = images.shape[2]
print(height, width)

N = 15*4
plt.figure(figsize=(14,8))
indices = np.linspace(0, len(times)*4-1, N).astype(int)
for i, index in enumerate(indices):
    plt.subplot(4, N//4, i+1)
    plt.imshow(images[index], vmin=-2, vmax=2)
    plt.xticks([])
    plt.yticks([])
    plt.xlim(0, width)
    plt.ylim(height, 0)    
    plt.scatter([targets[index,0]], [targets[index,1]])
# Out:
# 60 80

# %%
times, images, targets = davis_track.load_data('dvs_data/retinaTest95.events', dt=0.1, decay_time=0.1, 
                                               separate_channels=True, merge=2)
height = images.shape[1]//2
width = images.shape[2]
print(height, width)
N = 5
plt.figure(figsize=(14,8))
indices = np.linspace(0, len(times)-1, N).astype(int)
for i, index in enumerate(indices):
    plt.subplot(1, N, i+1)
    plt.imshow(images[index], vmin=-2, vmax=2)
    plt.xticks([])
    plt.yticks([])
    plt.xlim(0, width)
    plt.ylim(height*2, 0)    
    
    plt.scatter([targets[index,0]], [targets[index,1]])
    plt.scatter([targets[index,0]], [height+targets[index,1]])
# Out:
# 90 120

# %%
images, targets = davis_track.augment(images, targets, separate_channels=True)
N = 15*4
plt.figure(figsize=(14,8))
indices = np.linspace(0, len(times)*4-1, N).astype(int)
for i, index in enumerate(indices):
    plt.subplot(4, N//4, i+1)
    plt.imshow(images[index], vmin=-2, vmax=2)
    plt.xticks([])
    plt.yticks([])
    plt.xlim(0, width)
    plt.ylim(height*2, 0)    
    plt.scatter([targets[index,0]], [targets[index,1]])
    plt.scatter([targets[index,0]], [height+targets[index,1]])
